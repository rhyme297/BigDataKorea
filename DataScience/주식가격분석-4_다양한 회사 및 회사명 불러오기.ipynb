# %%
import mymodule.naver_finance_crawler2 as fin2

# %%
company_codes = ["005930", "000660", "005680", "034830", "035420", "015760"]

# %%
for company in company_codes:
    price = fin2.finance2(company)
    print(company, price)
# Out:
# 005930 40,500
# 000660 65,100
# 005680 11,550
# 034830 2,600
# 035420 131,000
# 015760 34,700

# %%
company_name = ["삼성전자", "하이닉스", "삼영전자", "한국토지신탁", "네이버", "한국전력"]

# %%
count = 0
for company in company_codes:
    price = fin2.finance2(company)
    print(company_name[count], company, price)
    count = count + 1
# Out:
# 삼성전자 005930 40,500
# 하이닉스 000660 65,100
# 삼영전자 005680 11,550
# 한국토지신탁 034830 2,600
# 네이버 035420 131,000
# 한국전력 015760 34,700
