# %%
import pandas as pd

# %%
Crime_Location = pd.read_excel('../data/02. 5Crime-location-convert.xls',  encoding='utf-8')

# %%
Crime_Location.head()
# Out:
#      기간      구분       계  아파트 연립다세대  단독주택     노상    상점  숙박업소목욕탕  유흥접객업소   사무실  \
# 0  2017       계  107835       4523  5092  32063  5047     1437    5077  1772
# 1  2017      살인     142         21    25     27     1        5      10     5
# 2  2017      강도     169         20    11     43    22        8       5     5
# 3  2017  강간강제추행    6963        319   413   1061   116      408     495   130
# 4  2017      절도   41162       1209  1340   8255  4119      670    1809   564
#
#   역대합실  교통수단  유원지   학교  금융기관     기타
# 0  908  2359  754  518  1024  47261
# 1    -     1    1    -     -     46
# 2    1     -    1    -     3     50
# 3  242  1105   51   49     1   2573
# 4  335   744  282  247   990  20598

# %%
Crime_Location[Crime_Location['구분'].isnull()] # Null 값인 경우 확인
# Out:
# Empty DataFrame
# Columns: [기간, 구분, 계, 아파트 연립다세대, 단독주택, 노상, 상점, 숙박업소목욕탕, 유흥접객업소, 사무실, 역대합실, 교통수단, 유원지, 학교, 금융기관, 기타]
# Index: []

# %%
Crime_Location.drop([0], inplace=True)

# %%
Crime_Location.head()
# Out:
#      기간      구분       계  아파트 연립다세대  단독주택     노상    상점  숙박업소목욕탕  유흥접객업소   사무실  \
# 0  2017       계  107835       4523  5092  32063  5047     1437    5077  1772
# 1  2017      살인     142         21    25     27     1        5      10     5
# 2  2017      강도     169         20    11     43    22        8       5     5
# 3  2017  강간강제추행    6963        319   413   1061   116      408     495   130
# 4  2017      절도   41162       1209  1340   8255  4119      670    1809   564
#
#   역대합실  교통수단  유원지   학교  금융기관     기타
# 0  908  2359  754  518  1024  47261
# 1    -     1    1    -     -     46
# 2    1     -    1    -     3     50
# 3  242  1105   51   49     1   2573
# 4  335   744  282  247   990  20598

# %%
del Crime_Location['기간']

# %%
Crime_Location.head()
# Out:
#        구분       계  아파트 연립다세대  단독주택     노상    상점  숙박업소목욕탕  유흥접객업소   사무실 역대합실  \
# 0       계  107835       4523  5092  32063  5047     1437    5077  1772  908
# 1      살인     142         21    25     27     1        5      10     5    -
# 2      강도     169         20    11     43    22        8       5     5    1
# 3  강간강제추행    6963        319   413   1061   116      408     495   130  242
# 4      절도   41162       1209  1340   8255  4119      670    1809   564  335
#
#    교통수단  유원지   학교  금융기관     기타
# 0  2359  754  518  1024  47261
# 1     1    1    -     -     46
# 2     -    1    -     3     50
# 3  1105   51   49     1   2573
# 4   744  282  247   990  20598

# %%
Crime_Location.set_index('구분', inplace=True)

# %%
Crime_Location.head()
# Out:
#              계  아파트 연립다세대  단독주택     노상    상점  숙박업소목욕탕  유흥접객업소   사무실 역대합실  \
# 구분
# 계       107835       4523  5092  32063  5047     1437    5077  1772  908
# 살인         142         21    25     27     1        5      10     5    -
# 강도         169         20    11     43    22        8       5     5    1
# 강간강제추행    6963        319   413   1061   116      408     495   130  242
# 절도       41162       1209  1340   8255  4119      670    1809   564  335
#
#         교통수단  유원지   학교  금융기관     기타
# 구분
# 계       2359  754  518  1024  47261
# 살인         1    1    -     -     46
# 강도         -    1    -     3     50
# 강간강제추행  1105   51   49     1   2573
# 절도       744  282  247   990  20598

# %%
import numpy as np

# %%
np.corrcoef(Crime_Location['계'], Crime_Location['아파트 연립다세대'])
# Out:
# array([[1.        , 0.96141594],
#        [0.96141594, 1.        ]])

# %%
import matplotlib.pyplot as plt  # matplotlib 는 한글 미지원. matplotlib 중 pyplot 이라는 명령어를 plt 라고 규정하여서 사용하겠다는 의미
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc  # matplotlib 의 한글 인식을 지원
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # Mac 인지 확인
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # Windows 인지 확인
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
plt.figure()

Crime_Location['계'].plot(kind='barh', grid=True, figsize=(10,10))

plt.show()
