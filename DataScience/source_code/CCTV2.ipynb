# %%
import pandas as pd

# %%
CCTV_Seoul = pd.read_csv('../data/01. CCTV_in_Seoul.csv',  encoding='utf-8')

# %%
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_Seoul.columns
# Out:
# Index(['기관명', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
CCTV_Seoul.rename(columns = {CCTV_Seoul.columns[0]:'구별'}, inplace=True)

# %%
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
pop_Seoul = pd.read_excel('../data/01. population_in_Seoul.xls',  encoding='utf-8')

# %%
pop_Seoul.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.1/4   합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3  2017.1/4  종로구    72654    162820    79675    83145   153589    75611
# 4  2017.1/4   중구    59481    133240    65790    67450   124312    61656
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5055408  270636  128445  142191   2.36   1321458
# 3    77978    9231    4064    5167   2.11     25425
# 4    62656    8928    4134    4794   2.09     20764

# %%
pop_Seoul = pd.read_excel('../data/01. population_in_Seoul.xls', 
                          header = 2,
                          usecols = 'B, D, G, J, N',
                          encoding='utf-8')

# %%
pop_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_Seoul.rename(columns={pop_Seoul.columns[0] : '구별', 
                          pop_Seoul.columns[1] : '인구수', 
                          pop_Seoul.columns[2] : '한국인', 
                          pop_Seoul.columns[3] : '외국인', 
                          pop_Seoul.columns[4] : '고령자'}, inplace=True)

# %%
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
CCTV_Seoul.sort_values(by='소계', ascending=True).head(5)
# Out:
#      구별   소계  2013년도 이전  2014년  2015년  2016년
# 9   도봉구  485        238    159     42    386
# 12  마포구  574        314    118    169    379
# 17  송파구  618        529     21     68    463
# 24  중랑구  660        509    121    177    109
# 23   중구  671        413    190     72    348

# %%
pop_Seoul.head(5)
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
pop_Seoul.drop([0], inplace=True)
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자
# 1    종로구  162820.0  153589.0   9231.0  25425.0
# 2     중구  133240.0  124312.0   8928.0  20764.0
# 3    용산구  244203.0  229456.0  14747.0  36231.0
# 4    성동구  311244.0  303380.0   7864.0  39997.0
# 5    광진구  372164.0  357211.0  14953.0  42214.0
# 6   동대문구  369496.0  354079.0  15417.0  54173.0
# 7    중랑구  414503.0  409882.0   4621.0  56774.0
# 8    성북구  461260.0  449773.0  11487.0  64692.0
# 9    강북구  330192.0  326686.0   3506.0  54813.0
# 10   도봉구  348646.0  346629.0   2017.0  51312.0
# 11   노원구  569384.0  565565.0   3819.0  71941.0
# 12   은평구  494388.0  489943.0   4445.0  72334.0
# 13  서대문구  327163.0  314982.0  12181.0  48161.0
# 14   마포구  389649.0  378566.0  11083.0  48765.0
# 15   양천구  479978.0  475949.0   4029.0  52975.0
# 16   강서구  603772.0  597248.0   6524.0  72548.0
# 17   구로구  447874.0  416487.0  31387.0  56833.0
# 18   금천구  255082.0  236353.0  18729.0  32970.0
# 19  영등포구  402985.0  368072.0  34913.0  52413.0
# ...

# %%
pop_Seoul['구별'].unique() #중복이 있는 경우 한 번만 표시: .unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', nan],
#       dtype=object)

# %%
pop_Seoul[pop_Seoul['구별'].isnull()] # Null 값인 경우 확인
# Out:
#      구별  인구수  한국인  외국인  고령자
# 26  NaN  NaN  NaN  NaN  NaN

# %%
pop_Seoul.drop([26], inplace=True)

# %%
pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
# Empty DataFrame
# Columns: [구별, 인구수, 한국인, 외국인, 고령자]
# Index: []

# %%
pop_Seoul['외국인비율'] = pop_Seoul['외국인'] / pop_Seoul['인구수'] * 100
pop_Seoul['고령자비율'] = pop_Seoul['고령자'] / pop_Seoul['인구수'] * 100

# %%
pop_Seoul.head()
# Out:
#     구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 1  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 4  성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 5  광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849

# %%
pop_Seoul.sort_values(by='인구수', ascending=True).head(5)
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 2    중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 1   종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 3   용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 18  금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 4   성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689

# %%
pop_Seoul.sort_values(by='인구수', ascending=False).head(5)
# Out:
#      구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 24  송파구  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 16  강서구  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 23  강남구  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 11  노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 21  관악구  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291

# %%
pop_Seoul.sort_values(by='외국인비율', ascending=True).head(5)
# Out:
#      구별       인구수       한국인     외국인      고령자     외국인비율      고령자비율
# 10  도봉구  348646.0  346629.0  2017.0  51312.0  0.578524  14.717507
# 11  노원구  569384.0  565565.0  3819.0  71941.0  0.670725  12.634883
# 15  양천구  479978.0  475949.0  4029.0  52975.0  0.839413  11.036964
# 23  강남구  570500.0  565550.0  4950.0  63167.0  0.867660  11.072217
# 12  은평구  494388.0  489943.0  4445.0  72334.0  0.899091  14.631019

# %%
pop_Seoul.sort_values(by='외국인비율', ascending=False).head(5)
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 19  영등포구  402985.0  368072.0  34913.0  52413.0  8.663598  13.006191
# 18   금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 17   구로구  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427

# %%
pop_Seoul.sort_values(by='고령자비율', ascending=False).head(5)
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 9    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 1    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797

# %%
CCTV_Seoul['최근증가율']=(CCTV_Seoul['2016년']+
                    CCTV_Seoul['2015년']+
                    CCTV_Seoul['2014년']) / CCTV_Seoul['2013년도 이전'] * 100

# %%
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 0  강남구  2780       1292    430    584    932  150.619195
# 1  강동구   773        379     99    155    377  166.490765
# 2  강북구   748        369    120    138    204  125.203252
# 3  강서구   884        388    258    184     81  134.793814
# 4  관악구  1496        846    260    390    613  149.290780

# %%
CCTV_Seoul.sort_values(by='최근증가율', ascending=False).head(5)
# Out:
#      구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율
# 22  종로구  1002        464    314    211    630  248.922414
# 9   도봉구   485        238    159     42    386  246.638655
# 12  마포구   574        314    118    169    379  212.101911
# 8   노원구  1265        542     57    451    516  188.929889
# 1   강동구   773        379     99    155    377  166.490765

# %%
data_result = pd.merge(CCTV_Seoul, pop_Seoul, on = '구별')
data_result.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년       최근증가율       인구수       한국인  \
# 0  강남구  2780       1292    430    584    932  150.619195  570500.0  565550.0
# 1  강동구   773        379     99    155    377  166.490765  453233.0  449019.0
# 2  강북구   748        369    120    138    204  125.203252  330192.0  326686.0
# 3  강서구   884        388    258    184     81  134.793814  603772.0  597248.0
# 4  관악구  1496        846    260    390    613  149.290780  525515.0  507203.0
#
#        외국인      고령자     외국인비율      고령자비율
# 0   4950.0  63167.0  0.867660  11.072217
# 1   4214.0  54622.0  0.929765  12.051638
# 2   3506.0  54813.0  1.061806  16.600342
# 3   6524.0  72548.0  1.080540  12.015794
# 4  18312.0  68082.0  3.484582  12.955291

# %%
del data_result['2013년도 이전']
del data_result['2014년']
del data_result['2015년']
del data_result['2016년']

# %%
data_result.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율
# 0  11.072217
# 1  12.051638
# 2  16.600342
# 3  12.015794
# 4  12.955291

# %%
data_result.set_index('구별', inplace=True)

# %%
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
import numpy as np

# %%
np.corrcoef(data_result['고령자비율'], data_result['소계'])
# Out:
# array([[ 1.        , -0.28078554],
#        [-0.28078554,  1.        ]])

# %%
np.corrcoef(data_result['외국인비율'], data_result['소계'])
# Out:
# array([[ 1.        , -0.13607433],
#        [-0.13607433,  1.        ]])

# %%
np.corrcoef(data_result['인구수'], data_result['소계'])
# Out:
# array([[1.        , 0.30634228],
#        [0.30634228, 1.        ]])

# %%
data_result.sort_values(by='인구수', ascending=False).head(5)
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 송파구   618  104.347826  667483.0  660584.0   6899.0  72506.0  1.033584
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 노원구  1265  188.929889  569384.0  565565.0   3819.0  71941.0  0.670725
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 송파구  10.862599
# 강서구  12.015794
# 강남구  11.072217
# 노원구  12.634883
# 관악구  12.955291

# %%
np.corrcoef(data_result['최근증가율'], data_result['소계'])
# Out:
# array([[ 1.      , -0.343016],
#        [-0.343016,  1.      ]])

# %%
from scipy.stats import pearsonr  #상관계수 및 유의도를 보기 위한 혼자 만의 스터디

# %%
import matplotlib.pyplot as plt  # matplotlib 는 한글 미지원. matplotlib 중 pyplot 이라는 명령어를 plt 라고 규정하여서 사용하겠다는 의미
# %matplotlib inline

# %%
plt.figure()
plt.plot([1,2,3,4,5,6,7,8,9,8,7,6,5,4,3,2,1])
plt.show()

# %%
pearsonr(data_result['최근증가율'], data_result['소계'])  #상관계수 및 유의도를 보기 위한 혼자 만의 스터디
# Out:
# (-0.34301599920153747, 0.09322138077721034)

# %%
pearsonr(data_result['최근증가율'], data_result['최근증가율'])  #상관계수 및 유의도를 보기 위한 혼자 만의 스터디
# Out:
# (1.0, 0.0)

# %%
t = np.arange(0, 12, 0.01)
y = np.sin(t)
z = np.cos(t)

plt.figure(figsize=(10,6))

plt.plot(t, y, label='sin', lw=5)
plt.plot(t, z, 'r', label='cos', lw=1)
plt.legend()

plt.grid()  #그래프 그리는 옵션은 plt.show() 앞쪽에 넣어야 함
plt.xlabel('time')
plt.ylabel('y-value')
plt.title('My sin & cos graph')

plt.show()

# %%
t = np.arange(0, 12, 0.01)
y = np.sin(t)
z = np.cos(t)

plt.figure(figsize=(10,6))

plt.plot(t, y, label='sin')
plt.plot(t, z, label='cos')
plt.legend()

plt.grid()  #그래프 그리는 옵션은 plt.show() 앞쪽에 넣어야 함
plt.xlabel('time')
plt.ylabel('y-value')
plt.title('My sin & cos graph')
plt.ylim(-1.2, 1.2)
plt.xlim(0, np.pi)  #np.pi는 상수

plt.show()

# %%
plt.figure(figsize=(10,6))

t = np.arange(0, 5, 0.5)

plt.plot(t, t, 'r--')
plt.plot(t, t*2, 'bs')
plt.plot(t, t*3, 'g^')
plt.plot(t, t*4, color='green', linestyle='dashed', marker='o')

plt.show()

# %%
s1 = np.random.normal(loc=0, scale=1, size=1000)
s2 = np.random.normal(loc=5, scale=0.5, size=1000)
s3 = np.random.normal(loc=10, scale=2, size=1000)
#loc는 평균값 scale은 표준편차, 1000개의 값을 random 하게 발생

# %%
plt.figure(figsize=(10,6))
plt.plot(s1, label='s1')
plt.plot(s2, label='s2')
plt.plot(s3, label='s3')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.boxplot((s1, s2, s3))
plt.grid()
plt.show()

# %%
import platform

from matplotlib import font_manager, rc  # matplotlib 의 한글 인식을 지원
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # Mac 인지 확인
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # Windows 인지 확인
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
data_result.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율
# 구별
# 강남구  11.072217
# 강동구  12.051638
# 강북구  16.600342
# 강서구  12.015794
# 관악구  12.955291

# %%
plt.figure()

data_result['소계'].plot(kind='barh', grid=True, figsize=(10,10))

plt.show()

# %%
plt.figure()

data_result['소계'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))

plt.show()

# %%
data_result['CCTV비율'] = data_result['소계'] / data_result['인구수'] * 100

plt.figure()

data_result['CCTV비율'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))

plt.show()

# %%
plt.figure(figsize=(6,6))

plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.xlabel('인구수')
plt.ylabel('CCTV 소계')
plt.grid()

plt.show()

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)  # 기울기와 절편을 구해주는 함수. "array(기울기, 절편)"
fp1
# Out:
# array([1.30916415e-03, 6.45066497e+02])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)  # x값의 시작은 100000, 끝은 700000, 간격은 100

# %%
plt.figure(figsize=(10,10))

plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='r')
plt.xlabel('인구수')
plt.ylabel('CCTV 소계')
plt.grid()

plt.show()

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

data_result['오차'] = np.abs(data_result['소계'] - f1(data_result['인구수']))

df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 송파구   618  104.347826  667483.0  660584.0   6899.0  72506.0  1.033584
# 양천구  2034   34.671731  479978.0  475949.0   4029.0  52975.0  0.839413
# 서초구  1930   63.371266  450310.0  445994.0   4316.0  51733.0  0.958451
# 용산구  1624   53.216374  244203.0  229456.0  14747.0  36231.0  6.038828
#
#          고령자비율    CCTV비율           오차
# 구별
# 강남구  11.072217  0.487292  1388.055355
# 송파구  10.862599  0.092587   900.911312
# 양천구  11.036964  0.423769   760.563512
# 서초구  11.488308  0.428594   695.403794
# 용산구  14.836427  0.665020   659.231690

# %%
plt.figure(figsize=(14,10))

plt.scatter(data_result['인구수'], data_result['소계'], 
            c=data_result['오차'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')

for n in range(10):
    plt.text(df_sort['인구수'][n]*1.02, df_sort['소계'][n]*0.98, 
             df_sort.index[n], fontsize=15)
    
plt.xlabel('인구수')
plt.ylabel('인구당비율')
plt.colorbar()
plt.grid()

plt.show()

# %%
Crime_Gu = pd.read_excel('../data/02. Crime-Gu.xls',  encoding='utf-8')

# %%
Crime_Gu.head()
# Out:
#    자치구  범죄건수
# 0  종로구  4577
# 1   중구  4851
# 2  용산구  3578
# 3  성동구  3190
# 4  광진구  5544

# %%
Crime_Gu.rename(columns={Crime_Gu.columns[0] : '구별'}, inplace=True)
Crime_Gu.head()
# Out:
#     구별  범죄건수
# 0  종로구  4577
# 1   중구  4851
# 2  용산구  3578
# 3  성동구  3190
# 4  광진구  5544

# %%
data_result2 = pd.merge(data_result, Crime_Gu, on = '구별')
data_result2.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율    CCTV비율           오차  범죄건수
# 0  11.072217  0.487292  1388.055355  8512
# 1  12.051638  0.170552   465.422892  4774
# 2  16.600342  0.226535   329.342026  3928
# 3  12.015794  0.146413   551.503155  5098
# 4  12.955291  0.284673   162.948104  6233

# %%
plt.figure(figsize=(6,6))

plt.scatter(data_result2['범죄건수'], data_result2['CCTV비율'], s=50)
plt.xlabel('범죄건수')
plt.ylabel('CCTV비율')
plt.grid()

plt.show()

# %%
fp1 = np.polyfit(data_result2['범죄건수'], data_result2['CCTV비율'], 1)  # 기울기와 절편을 구해주는 함수. "array(기울기, 절편)"
fp1
# Out:
# array([-8.20301233e-06,  3.51827629e-01])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(2000, 10000, 10)  # x값의 시작은 100000, 끝은 700000, 간격은 100

# %%
plt.figure(figsize=(10,10))

plt.scatter(data_result2['범죄건수'], data_result2['CCTV비율'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='r')
plt.xlabel('범죄건수')
plt.ylabel('CCTV비율')
plt.grid()

plt.show()

# %%
fp1 = np.polyfit(data_result2['범죄건수'], data_result2['CCTV비율'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(2000, 10000, 10)

data_result2['오차2'] = np.abs(data_result2['범죄건수'] - f1(data_result2['소계']))

df_sort = data_result2.sort_values(by='오차2', ascending=False)
df_sort.head()
# Out:
#         소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구   2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 영등포구   904  157.979798  402985.0  368072.0  34913.0  52413.0  8.663598
# 송파구    618  104.347826  667483.0  660584.0   6899.0  72506.0  1.033584
# 관악구   1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
# 마포구    574  212.101911  389649.0  378566.0  11083.0  48765.0  2.844355
#
#           고령자비율    CCTV비율           오차  범죄건수          오차2
# 구별
# 강남구   11.072217  0.487292  1388.055355  8512  8511.670977
# 영등포구  13.006191  0.224326   268.640012  6551  6550.655588
# 송파구   10.862599  0.092587   900.911312  6317  6316.653242
# 관악구   12.955291  0.284673   162.948104  6233  6232.660444
# 마포구   12.515110  0.147312   581.180999  5720  5719.652881

# %%
data_result2.set_index('구별', inplace=True)
data_result2.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율    CCTV비율           오차  범죄건수          오차2
# 구별
# 강남구  11.072217  0.487292  1388.055355  8512  8511.670977
# 강동구  12.051638  0.170552   465.422892  4774  4773.654513
# 강북구  16.600342  0.226535   329.342026  3928  3927.654308
# 강서구  12.015794  0.146413   551.503155  5098  5097.655424
# 관악구  12.955291  0.284673   162.948104  6233  6232.660444

# %%
plt.figure(figsize=(14,10))

plt.scatter(data_result2['범죄건수'], data_result2['CCTV비율'], 
            c=data_result2['오차2'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')

for n in range(10):
    plt.text(df_sort['범죄건수'][n]*1.02, df_sort['CCTV비율'][n]*0.98, 
             df_sort.index[n], fontsize=15)
    
plt.xlabel('범죄건수')
plt.ylabel('CCTV비율')
plt.colorbar()
plt.grid()

plt.show()
