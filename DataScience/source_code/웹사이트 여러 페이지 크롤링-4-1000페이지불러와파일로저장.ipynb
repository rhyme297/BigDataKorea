# %%
import mymodule.naver_api_caller3 as caller3

# %%
#call함수를 호출해보자.
caller3.call("강남역 맛집", 1)
# Out:
# <Response [200]>
# {'lastBuildDate': 'Sat, 12 Jan 2019 21:46:38 +0900',
#  'total': 189774,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '<b>강남역 맛집</b> 여자들이 좋아할만해!',
#    'link': 'http://blog.naver.com/talk442?Redirect=Log&amp;logNo=221439805503',
#    'description': '찾다가<b>강남역 맛집</b> 중 102J라는 곳이 눈에 띄더라고요. 후기를 보니 민트민트하고 고급스러운게 딱 언니들 취향이라 단톡방에 여기를 가자고 했더니 다들 찬성을 해서 만장일치로 결정을 했어요. 처음에는 강남... ',
#    'bloggername': '비키의 소소한일상:)',
#    'bloggerlink': 'http://blog.naver.com/talk442',
#    'postdate': '20190111'},
#   {'title': '<b>강남역 맛집</b> 매운갈비찜의 정석 신맵당!',
#    'link': 'http://blog.naver.com/llillo2?Redirect=Log&amp;logNo=221435572066',
#    'description': '함께 강남역에서 쇼핑하고 인생 첫 클라이밍을 즐기러 가기 전에 점심 식사로 들렸던 <b>강남역 맛집</b> 매운... 주변엔 회사도 많아 강남역 회식장소나 모임 장소로도 인기가 높은 맛집이기에 혹시나 여럿이서 방문을... ',
#    'bloggername': '우기부기블로그',
#    'bloggerlink': 'http://blog.naver.com/llillo2',
#    'postdate': '20190106'},
#   {'title': '<b>강남역 맛집</b> 색다른 나폴리회관',
# ...

# %%
#get1000Result함수를 호출해보자.
result = caller3.get1000Result("강남역 맛집")
print(result)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
print(len(result))
#결과가 100개가 나옴.
# Out:
# 1000

# %%
result2 = caller3.get1000Result("강남역 찻집")
print(result2)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ...

# %%
list = []
list = result + result2

print(len(list))
# Out:
# 2000

# %%
import json

# %%
# list를 json으로 변환해줌=> json.dumps(list)
file = open("./gangnam.json", "w+")
file.write(json.dumps(list))
# Out:
# 1762250
