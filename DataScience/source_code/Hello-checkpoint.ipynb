# %%
print(100)
# Out:
# 100

# %%
a = 100

# %%
b = 200

# %%
a+b
# Out:
# 300

# %%
subject = ['안드로이드', '파이썬', '자바']

# %%
subject
# Out:
# ['안드로이드', '파이썬', '자바']

# %%
subject[2]
# Out:
# '자바'

# %%
#실행은 쉬프트 + 엔터
#주석은 #을 이용
#셀을 삽입할 때는 알트+엔터
#셀을 지울때는 지울셀 선택 후, dd

# %%
c = "감자"
d = "복숭아"
print(c)
print(d)
# Out:
# 감자
# 복숭아

# %%
subject
# Out:
# ['안드로이드', '파이썬', '자바']

# %%
len(subject)
# Out:
# 3

# %%
for x in subject:
    print(x)
    
print("============")
# Out:
# 안드로이드
# 파이썬
# 자바
# ...

# %%
for x in range(len(subject)):
    print(subject[x])
# Out:
# 안드로이드
# 파이썬
# 자바

# %%
food = ["감자", "고구마", "양파"]
food
# Out:
# ['감자', '고구마', '양파']

# %%
food[2] = input("음식을 입력해주세요.")
# Out:
# 음식을 입력해주세요.피자

# %%
food
# Out:
# ['감자', '고구마', '피자']

# %%
food.append("우유")

# %%
food
# Out:
# ['감자', '고구마', '피자', '우유']

# %%
food.remove(food[0])

# %%
food
# Out:
# ['고구마', '피자', '우유']
