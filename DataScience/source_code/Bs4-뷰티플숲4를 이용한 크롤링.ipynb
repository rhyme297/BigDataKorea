# %%
import bs4

# %%
html_str = "<html><div></div></html>"

# %%
bsObj = bs4.BeautifulSoup(html_str, "html.parser")

# %%
print(type(bsObj))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(bsObj)
# Out:
# <html><div></div></html>

# %%
bsObj.find("div")
# Out:
# <div></div>
