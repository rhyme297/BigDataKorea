# %%
import os

# %%
print("현재 운영체제: ", os.name)
# Out:
# 현재 운영체제:  nt

# %%
print("현재 작업폴더: ", os.getcwd())
# Out:
# 현재 작업폴더:  C:\Users\PC\Documents\DataScience\source_code

# %%
with open("file3.txt", "w") as file:
    file.write("hello~~~~~~~~~\n I am file Contents...") # \n 은 엔터의 의미. 원래는 \n과 I am 사이를 붙어야 예쁘게 들어감. 지금은 스페이스 하나 먹음
    
# os.system("dir") # 컨트롤 + / 는 주석 단축키

os.rename("file3.txt", "newFile.txt") # newFile.txt 추가

# %%
os.remove("newFile.txt") # newFile.txt 삭제
